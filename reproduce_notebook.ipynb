# %% [markdown]
# # CIFAR-10-C AI-Claim Audit Reproduction Notebook
#
# This notebook records the commands and artifact paths for reproducing the MILS AI-Claim Audit experiment. The full results are already generated in `final_submission/evidence/`.

# %% [markdown]
# ## Dataset and Model Paths
#
# - Clean CIFAR-10: `/ssd1/datasets/cifar10`
# - CIFAR-10-C: `/ssd3/fan/hw/data/CIFAR-10-C`
# - Model code: `/ssd1/hsiao/statpruning/pytorch_resnet_cifar10-master/resnet_cifar10.py`
# - Checkpoints: `resnet20.th`, `resnet56.th`

# %%
# !env MPLCONFIGDIR=/tmp/matplotlib \
  /home/wang256hep/miniconda3/envs/aigi_cu129/bin/python \
  /ssd3/fan/hw/cifar10c_audit/evaluate_cifar10c.py \
  --smoke --batch_size 256

# %%
# !env MPLCONFIGDIR=/tmp/matplotlib \
  /home/wang256hep/miniconda3/envs/aigi_cu129/bin/python \
  /ssd3/fan/hw/cifar10c_audit/evaluate_cifar10c.py \
  --batch_size 1024

# %%
# !env MPLCONFIGDIR=/tmp/matplotlib \
  /home/wang256hep/miniconda3/envs/aigi_cu129/bin/python \
  /ssd3/fan/hw/cifar10c_audit/final_submission/code/generate_report_assets.py

# %% [markdown]
# ## Key Output Files
#
# - `evidence/results.csv`
# - `evidence/claim_audit.csv`
# - `evidence/failure_cases.csv`
# - `evidence/audit_recheck.json`
# - `report_final_draft.md`
# - `ai_collaboration_log.md`
